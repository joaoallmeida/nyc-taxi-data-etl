# %%
import duckdb

# %%
conn = duckdb.connect('/tmp/duckdb.db')

# %%
conn.query('SHOW ALL TABLES')
# Out:
# ┌──────────┬─────────┬──────────────────────┬──────────────────────┬───────────────────────────────────────┬───────────┐
# │ database │ schema  │         name         │     column_names     │             column_types              │ temporary │
# │ varchar  │ varchar │       varchar        │      varchar[]       │               varchar[]               │  boolean  │
# ├──────────┼─────────┼──────────────────────┼──────────────────────┼───────────────────────────────────────┼───────────┤
# │ duckdb   │ bronze  │ raw_fhv_trip_records │ [dispatching_base_…  │ [VARCHAR, TIMESTAMP, TIMESTAMP, BIG…  │ false     │
# │ duckdb   │ bronze  │ raw_green_taxi_tri…  │ [VendorID, lpep_pi…  │ [INTEGER, TIMESTAMP, TIMESTAMP, VAR…  │ false     │
# │ duckdb   │ bronze  │ raw_yellow_taxi_tr…  │ [VendorID, tpep_pi…  │ [INTEGER, TIMESTAMP, TIMESTAMP, BIG…  │ false     │
# │ duckdb   │ silver  │ fhv_trips            │ [dispatching_base_…  │ [VARCHAR, TIMESTAMP, TIMESTAMP, BIG…  │ false     │
# ...

# %%
df = conn.query("SELECT * FROM silver.green_trips LIMIT 10").df()

# %%
df
# Out:
#          vendor lpep_pickup_datetime lpep_dropoff_datetime  \
# 0  VeriFone Inc  2024-04-01 00:18:50   2024-04-01 00:19:48
# 1  VeriFone Inc  2024-04-01 00:56:16   2024-04-01 01:12:56
# 2  VeriFone Inc  2024-04-01 00:23:09   2024-04-01 00:33:03
# 3  VeriFone Inc  2024-03-31 22:34:23   2024-03-31 22:45:33
# 4  VeriFone Inc  2024-03-31 23:21:41   2024-03-31 23:29:40
# 5  VeriFone Inc  2024-04-01 00:41:53   2024-04-01 00:50:31
# 6  VeriFone Inc  2024-04-01 00:26:37   2024-04-01 00:32:16
# 7  VeriFone Inc  2024-04-01 00:26:57   2024-04-01 00:35:21
# 8  VeriFone Inc  2024-04-01 00:54:37   2024-04-01 01:05:48
# 9  VeriFone Inc  2024-04-01 00:00:48   2024-04-01 00:13:44
#
#              store_and_fwd_flag       ratecode  PULocationID  DOLocationID  \
# 0  NOT A STORE AND FORWARD TRIP  STANDARD RATE           146           146
# 1  NOT A STORE AND FORWARD TRIP  STANDARD RATE            65           225
# 2  NOT A STORE AND FORWARD TRIP  STANDARD RATE           226           146
# ...
